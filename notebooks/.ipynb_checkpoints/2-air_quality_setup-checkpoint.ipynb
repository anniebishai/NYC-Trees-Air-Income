# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np

# %%
air = pd.read_csv('../data/air_quality/Air_Quality.csv')
# https://data.cityofnewyork.us/Environment/Air-Quality/c3uy-2p5r
cd = gpd.read_file('../data/shapefiles/nycd_22a/nycd.shp')

# %%
air['Name'].unique()
# Out:
# array(['Fine Particulate Matter (PM2.5)', 'Ozone (O3)',
#        'Sulfur Dioxide (SO2)', 'Nitrogen Dioxide (NO2)',
#        'PM2.5-Attributable Deaths',
#        'Boiler Emissions- Total SO2 Emissions',
#        'Boiler Emissions- Total PM2.5 Emissions',
#        'Boiler Emissions- Total NOx Emissions',
#        'Traffic Density- Annual Vehicle Miles Traveled',
#        'Traffic Density- Annual Vehicle Miles Traveled for Cars',
#        'Traffic Density- Annual Vehicle Miles Traveled for Trucks',
#        'Air Toxics Concentrations- Average Benzene Concentrations',
#        'Air Toxics Concentrations- Average Formaldehyde Concentrations',
#        'PM2.5-Attributable Asthma Emergency Department Visits',
#        'PM2.5-Attributable Respiratory Hospitalizations (Adults 20 Yrs and Older)',
#        'O3-Attributable Cardiac and Respiratory Deaths',
#        'PM2.5-Attributable Cardiovascular Hospitalizations (Adults 40 Yrs and Older)',
#        'O3-Attributable Asthma Emergency Department Visits',
#        'O3-Attributable Asthma Hospitalizations'], dtype=object)

# %%
air.head()
# Out:
#    Unique ID  Indicator ID                             Name Measure  \
# 0     333939           365  Fine Particulate Matter (PM2.5)    Mean
# 1     547354           365  Fine Particulate Matter (PM2.5)    Mean
# 2     605650           365  Fine Particulate Matter (PM2.5)    Mean
# 3     179503           365  Fine Particulate Matter (PM2.5)    Mean
# 4     179643           365  Fine Particulate Matter (PM2.5)    Mean
#
#           Measure Info Geo Type Name  Geo Join ID Geo Place Name  \
# 0  mcg per cubic meter       Borough            1          Bronx
# 1  mcg per cubic meter       Borough            1          Bronx
# 2  mcg per cubic meter       Borough            1          Bronx
# 3  mcg per cubic meter       Borough            1          Bronx
# 4  mcg per cubic meter       Borough            1          Bronx
#
#            Time Period  Start_Date  Data Value  Message
# 0       Winter 2014-15  12/01/2014       10.21      NaN
# 1  Annual Average 2017  01/01/2017        7.72      NaN
# 2       Winter 2017-18  12/01/2017        8.28      NaN
# 3       Winter 2010-11  12/01/2010       13.85      NaN
# 4  Annual Average 2009  12/01/2008       11.05      NaN

# %%
air['Geo Type Name'].unique()
# Out:
# array(['Borough', 'UHF34', 'UHF42', 'CD', 'Citywide'], dtype=object)

# %%
# Limit to entries measured by CD

air = air[air['Geo Type Name'] == 'CD']

# %%
air.shape
# Out:
# (5133, 12)

# %%
# Create columns for CD and borough

air.rename(columns = {'Geo Join ID': 'CD'}, inplace=True)

#air['CD_num'] = air['Geo Place Name'].map(lambda x: x.split('CD')[-1][:-1])
air['borough'] = air['CD'].map(lambda x: int(str(x)[0]))

# %%
air.head()
# Out:
#      Unique ID  Indicator ID                             Name Measure  \
# 253     169573           365  Fine Particulate Matter (PM2.5)    Mean
# 254     170281           365  Fine Particulate Matter (PM2.5)    Mean
# 259     547775           365  Fine Particulate Matter (PM2.5)    Mean
# 260     606069           365  Fine Particulate Matter (PM2.5)    Mean
# 261     168511           365  Fine Particulate Matter (PM2.5)    Mean
#
#             Measure Info Geo Type Name   CD  \
# 253  mcg per cubic meter            CD  503
# 254  mcg per cubic meter            CD  503
# 259  mcg per cubic meter            CD  503
# 260  mcg per cubic meter            CD  503
# 261  mcg per cubic meter            CD  503
#
#                         Geo Place Name          Time Period  Start_Date  \
# 253  Tottenville and Great Kills (CD3)          Summer 2013  06/01/2013
# 254  Tottenville and Great Kills (CD3)  Annual Average 2010  12/01/2009
# 259  Tottenville and Great Kills (CD3)       Winter 2016-17  12/01/2016
# 260  Tottenville and Great Kills (CD3)          Summer 2018  06/01/2018
# 261  Tottenville and Great Kills (CD3)       Winter 2009-10  12/01/2009
#
#      Data Value  Message  borough
# 253        9.13      NaN        5
# 254        8.75      NaN        5
# 259        6.87      NaN        5
# 260        7.36      NaN        5
# 261        9.07      NaN        5

# %%
# How many unique community districts?
air['CD'].unique()
# Out:
# array([503, 502, 501, 414, 413, 412, 411, 410, 409, 408, 407, 406, 405,
#        404, 403, 402, 401, 318, 317, 316, 315, 314, 313, 312, 311, 310,
#        309, 308, 307, 306, 305, 304, 303, 302, 301, 212, 211, 210, 209,
#        208, 207, 206, 205, 204, 203, 202, 201, 112, 111, 110, 109, 108,
#        107, 106, 105, 104, 103, 102, 101])

# %%
air.drop(columns=['Unique ID', 'Indicator ID', 'Geo Type Name', 'Message'], inplace=True)

# %% [markdown]
# ### Determine which time periods to use

# %%
## Fine particulate matter geo category breakdown and times measured
fpm = air[air['Name'] == 'Fine Particulate Matter (PM2.5)']
fpm.groupby('Time Period').count()
# Out:
#                      Name  Measure  Measure Info  CD  Geo Place Name  \
# Time Period
# Annual Average 2009    59       59            59  59              59
# Annual Average 2010    59       59            59  59              59
# Annual Average 2011    59       59            59  59              59
# Annual Average 2012    59       59            59  59              59
# Annual Average 2013    59       59            59  59              59
# Annual Average 2014    59       59            59  59              59
# Annual Average 2015    59       59            59  59              59
# Annual Average 2016    59       59            59  59              59
# Annual Average 2017    59       59            59  59              59
# Annual Average 2018    59       59            59  59              59
# Summer 2009            59       59            59  59              59
# Summer 2010            59       59            59  59              59
# Summer 2011            59       59            59  59              59
# Summer 2012            59       59            59  59              59
# Summer 2013            59       59            59  59              59
# Summer 2014            59       59            59  59              59
# Summer 2015            59       59            59  59              59
# Summer 2016            59       59            59  59              59
# Summer 2017            59       59            59  59              59
# Summer 2018            59       59            59  59              59
# Winter 2008-09         59       59            59  59              59
# Winter 2009-10         59       59            59  59              59
# Winter 2010-11         59       59            59  59              59
# Winter 2011-12         59       59            59  59              59
# Winter 2012-13         59       59            59  59              59
# Winter 2013-14         59       59            59  59              59
# Winter 2014-15         59       59            59  59              59
# Winter 2015-16         59       59            59  59              59
# Winter 2016-17         59       59            59  59              59
# Winter 2017-18         59       59            59  59              59
#
#                      Start_Date  Data Value  borough
# Time Period
# Annual Average 2009          59          59       59
# Annual Average 2010          59          59       59
# Annual Average 2011          59          59       59
# Annual Average 2012          59          59       59
# Annual Average 2013          59          59       59
# Annual Average 2014          59          59       59
# Annual Average 2015          59          59       59
# Annual Average 2016          59          59       59
# Annual Average 2017          59          59       59
# Annual Average 2018          59          59       59
# Summer 2009                  59          59       59
# Summer 2010                  59          59       59
# Summer 2011                  59          59       59
# Summer 2012                  59          59       59
# Summer 2013                  59          59       59
# Summer 2014                  59          59       59
# Summer 2015                  59          59       59
# Summer 2016                  59          59       59
# Summer 2017                  59          59       59
# Summer 2018                  59          59       59
# Winter 2008-09               59          59       59
# Winter 2009-10               59          59       59
# Winter 2010-11               59          59       59
# Winter 2011-12               59          59       59
# Winter 2012-13               59          59       59
# Winter 2013-14               59          59       59
# Winter 2014-15               59          59       59
# Winter 2015-16               59          59       59
# Winter 2016-17               59          59       59
# Winter 2017-18               59          59       59

# %%
## Traffic density geo category breakdown and times measured 
traffic_density = air[air['Name'] == 'Traffic Density- Annual Vehicle Miles Traveled']
traffic_density.groupby('Time Period').count()
# Out:
#              Name  Measure  Measure Info  CD  Geo Place Name  Start_Date  \
# Time Period
# 2005           59       59            59  59              59          59
# 2016           59       59            59  59              59          59
#
#              Data Value  borough
# Time Period
# 2005                 59       59
# 2016                 59       59

# %%
# Nitrogen dioxide geo category breakdown and times measured
NO2 = air[air['Name'] == 'Nitrogen Dioxide (NO2)']
NO2.groupby('Time Period').count()
# Out:
#                      Name  Measure  Measure Info  CD  Geo Place Name  \
# Time Period
# Annual Average 2009    59       59            59  59              59
# Annual Average 2010    59       59            59  59              59
# Annual Average 2011    59       59            59  59              59
# Annual Average 2012    59       59            59  59              59
# Annual Average 2013    59       59            59  59              59
# Annual Average 2014    59       59            59  59              59
# Annual Average 2015    59       59            59  59              59
# Annual Average 2016    59       59            59  59              59
# Annual Average 2017    59       59            59  59              59
# Annual Average 2018    59       59            59  59              59
# Summer 2009            59       59            59  59              59
# Summer 2010            59       59            59  59              59
# Summer 2011            59       59            59  59              59
# Summer 2012            59       59            59  59              59
# Summer 2013            59       59            59  59              59
# Summer 2014            59       59            59  59              59
# Summer 2015            59       59            59  59              59
# Summer 2016            59       59            59  59              59
# Summer 2017            59       59            59  59              59
# Summer 2018            59       59            59  59              59
# Winter 2008-09         59       59            59  59              59
# Winter 2009-10         59       59            59  59              59
# Winter 2010-11         59       59            59  59              59
# Winter 2011-12         59       59            59  59              59
# Winter 2012-13         59       59            59  59              59
# Winter 2013-14         59       59            59  59              59
# Winter 2014-15         59       59            59  59              59
# Winter 2015-16         59       59            59  59              59
# Winter 2016-17         59       59            59  59              59
# Winter 2017-18         59       59            59  59              59
#
#                      Start_Date  Data Value  borough
# Time Period
# Annual Average 2009          59          59       59
# Annual Average 2010          59          59       59
# Annual Average 2011          59          59       59
# Annual Average 2012          59          59       59
# Annual Average 2013          59          59       59
# Annual Average 2014          59          59       59
# Annual Average 2015          59          59       59
# Annual Average 2016          59          59       59
# Annual Average 2017          59          59       59
# Annual Average 2018          59          59       59
# Summer 2009                  59          59       59
# Summer 2010                  59          59       59
# Summer 2011                  59          59       59
# Summer 2012                  59          59       59
# Summer 2013                  59          59       59
# Summer 2014                  59          59       59
# Summer 2015                  59          59       59
# Summer 2016                  59          59       59
# Summer 2017                  59          59       59
# Summer 2018                  59          59       59
# Winter 2008-09               59          59       59
# Winter 2009-10               59          59       59
# Winter 2010-11               59          59       59
# Winter 2011-12               59          59       59
# Winter 2012-13               59          59       59
# Winter 2013-14               59          59       59
# Winter 2014-15               59          59       59
# Winter 2015-16               59          59       59
# Winter 2016-17               59          59       59
# Winter 2017-18               59          59       59

# %%
ozone = air[air['Name'] == 'Ozone (O3)']
ozone.groupby('Time Period').count()
# Out:
#                                  Name  Measure  Measure Info  CD  \
# Time Period
# 2-Year Summer Average 2009-2010    59       59            59  59
# Summer 2009                        59       59            59  59
# Summer 2010                        59       59            59  59
# Summer 2011                        59       59            59  59
# Summer 2012                        59       59            59  59
# Summer 2013                        59       59            59  59
# Summer 2014                        59       59            59  59
# Summer 2015                        59       59            59  59
# Summer 2016                        59       59            59  59
# Summer 2017                        59       59            59  59
# Summer 2018                        59       59            59  59
#
#                                  Geo Place Name  Start_Date  Data Value  \
# Time Period
# 2-Year Summer Average 2009-2010              59          59          59
# Summer 2009                                  59          59          59
# Summer 2010                                  59          59          59
# Summer 2011                                  59          59          59
# Summer 2012                                  59          59          59
# Summer 2013                                  59          59          59
# Summer 2014                                  59          59          59
# Summer 2015                                  59          59          59
# Summer 2016                                  59          59          59
# Summer 2017                                  59          59          59
# Summer 2018                                  59          59          59
#
#                                  borough
# Time Period
# 2-Year Summer Average 2009-2010       59
# Summer 2009                           59
# Summer 2010                           59
# Summer 2011                           59
# Summer 2012                           59
# Summer 2013                           59
# Summer 2014                           59
# Summer 2015                           59
# Summer 2016                           59
# Summer 2017                           59
# Summer 2018                           59

# %%
SO2 = air[air['Name'] == 'Sulfur Dioxide (SO2)']
SO2.groupby('Time Period').count()
# Out:
#                 Name  Measure  Measure Info  CD  Geo Place Name  Start_Date  \
# Time Period
# Winter 2008-09    59       59            59  59              59          59
# Winter 2009-10    59       59            59  59              59          59
# Winter 2010-11    59       59            59  59              59          59
# Winter 2011-12    59       59            59  59              59          59
# Winter 2012-13    59       59            59  59              59          59
# Winter 2013-14    59       59            59  59              59          59
# Winter 2014-15    59       59            59  59              59          59
# Winter 2015-16    59       59            59  59              59          59
#
#                 Data Value  borough
# Time Period
# Winter 2008-09          59       59
# Winter 2009-10          59       59
# Winter 2010-11          59       59
# Winter 2011-12          59       59
# Winter 2012-13          59       59
# Winter 2013-14          59       59
# Winter 2014-15          59       59
# Winter 2015-16          59       59

# %%
air['Name'].value_counts()
# Out:
# Fine Particulate Matter (PM2.5)                                   1770
# Nitrogen Dioxide (NO2)                                            1770
# Ozone (O3)                                                         649
# Sulfur Dioxide (SO2)                                               472
# Traffic Density- Annual Vehicle Miles Traveled                     118
# Traffic Density- Annual Vehicle Miles Traveled for Cars            118
# Traffic Density- Annual Vehicle Miles Traveled for Trucks          118
# Air Toxics Concentrations- Average Benzene Concentrations           59
# Air Toxics Concentrations- Average Formaldehyde Concentrations      59
# Name: Name, dtype: int64

# %%
# Remove air toxics concentrations, change name to df

df = air[~air['Name'].str.contains('Toxics', regex=False)].copy()

# %%
df[['CD', 'Geo Place Name']]
cd_dict = {}
for x in df['CD'].unique():
    first = df[df['CD'] == x].index[0]
    cd_dict[x] = df.loc[first, 'Geo Place Name']

# %% [markdown]
# ## Create df with specific measured values at diff times for each CD

# %%
# rename measures
name_dict = {
    'Fine Particulate Matter (PM2.5)': 'FPM',
    'Nitrogen Dioxide (NO2)': 'NO2',
    'Ozone (O3)': 'O3',
    'Sulfur Dioxide (SO2)': 'SO2',
    'Traffic Density- Annual Vehicle Miles Traveled': 'TrafficDens_Vehicle',
    'Traffic Density- Annual Vehicle Miles Traveled for Cars': 'TrafficDens_Car',
    'Traffic Density- Annual Vehicle Miles Traveled for Trucks': 'TrafficDens_Truck'}
df['Name'] = df['Name'].map(name_dict)

# %%
# change start date to datetime
# df['Start_Date'] = pd.to_datetime(df['Start_Date'])

# Create column combining time period and measure name 
df['Date_Name'] = df['Time Period'].map(lambda x: ' '.join(x.split(' ')[::-1])) + '_' + df['Name']
df.head()
# Out:
#     Name Measure         Measure Info   CD                     Geo Place Name  \
# 253  FPM    Mean  mcg per cubic meter  503  Tottenville and Great Kills (CD3)
# 254  FPM    Mean  mcg per cubic meter  503  Tottenville and Great Kills (CD3)
# 259  FPM    Mean  mcg per cubic meter  503  Tottenville and Great Kills (CD3)
# 260  FPM    Mean  mcg per cubic meter  503  Tottenville and Great Kills (CD3)
# 261  FPM    Mean  mcg per cubic meter  503  Tottenville and Great Kills (CD3)
#
#              Time Period  Start_Date  Data Value  borough  \
# 253          Summer 2013  06/01/2013        9.13        5
# 254  Annual Average 2010  12/01/2009        8.75        5
# 259       Winter 2016-17  12/01/2016        6.87        5
# 260          Summer 2018  06/01/2018        7.36        5
# 261       Winter 2009-10  12/01/2009        9.07        5
#
#                    Date_Name
# 253          2013 Summer_FPM
# 254  2010 Average Annual_FPM
# 259       2016-17 Winter_FPM
# 260          2018 Summer_FPM
# 261       2009-10 Winter_FPM

# %%
# Drop rows with unwanted (redundant) start dates
ind1 = df[df['Name'] == 'NO2'].loc[df['Time Period'].str.startswith('Annual')].index # annual NO2
ind2 = df[df['Name'] == 'FPM'].loc[df['Time Period'].str.startswith('Annual')].index # annual FMP
ind3 = df[df['Name'] == 'O3'].loc[df['Time Period'].str.startswith('2-y')].index # two-year O2

ind_to_drop = ind1.append(ind2).append(ind3)
df.drop(ind_to_drop, inplace=True)

# %%
df.head()
# Out:
#     Name Measure         Measure Info   CD                     Geo Place Name  \
# 253  FPM    Mean  mcg per cubic meter  503  Tottenville and Great Kills (CD3)
# 259  FPM    Mean  mcg per cubic meter  503  Tottenville and Great Kills (CD3)
# 260  FPM    Mean  mcg per cubic meter  503  Tottenville and Great Kills (CD3)
# 261  FPM    Mean  mcg per cubic meter  503  Tottenville and Great Kills (CD3)
# 262  FPM    Mean  mcg per cubic meter  503  Tottenville and Great Kills (CD3)
#
#         Time Period  Start_Date  Data Value  borough           Date_Name
# 253     Summer 2013  06/01/2013        9.13        5     2013 Summer_FPM
# 259  Winter 2016-17  12/01/2016        6.87        5  2016-17 Winter_FPM
# 260     Summer 2018  06/01/2018        7.36        5     2018 Summer_FPM
# 261  Winter 2009-10  12/01/2009        9.07        5  2009-10 Winter_FPM
# 262  Winter 2012-13  12/01/2012        9.60        5  2012-13 Winter_FPM

# %%
df['CD'].dtype
# Out:
# dtype('int64')

# %%
len(df['CD'].unique())
# Out:
# 59

# %%
# Create a separate dataframe for each community district

dfs = []

for x in df['CD'].unique():
    cd_df = df[df['CD'] == x].copy()[['Date_Name', 'Data Value']]
    cd_df.set_index('Date_Name', inplace=True)
    cd_df.rename(columns={'Data Value': x}, inplace=True)
    dfs.append(cd_df)

# %%
#[df.shape for df in dfs]

# %%
[x for x in dfs[0].index if x not in dfs[1].index]
# Out:
# []

# %%
[x for x in dfs[1].index if x not in dfs[0].index]
# Out:
# []

# %%
# Merge individual dataframes

air_qual = dfs[0]

for i in range(1,59):
    air_qual = pd.merge(air_qual, dfs[i], left_on='Date_Name', right_on='Date_Name')

# %%
air_qual.shape
# Out:
# (65, 59)

# %%
air_qual = air_qual.T
air_qual['CD_Name'] = air_qual.index.map(cd_dict)
air_qual.head()
# Out:
# Date_Name  2013 Summer_FPM  2016-17 Winter_FPM  2018 Summer_FPM  \
# 503                   9.13                6.87             7.36
# 502                   9.41                7.17             7.62
# 501                   9.47                7.23             7.65
# 414                   9.44                7.29             7.75
# 413                   9.77                7.72             8.07
#
# Date_Name  2009-10 Winter_FPM  2012-13 Winter_FPM  2009 Summer_FPM  \
# 503                      9.07                9.60            10.39
# 502                      9.02                9.76            10.56
# 501                      9.15                9.85            10.58
# 414                      7.94                9.23             9.60
# 413                      8.86                9.29             9.67
#
# Date_Name  2010 Summer_FPM  2010-11 Winter_FPM  2015 Summer_FPM  \
# 503                  11.27               11.52             8.44
# 502                  11.51               11.65             8.77
# 501                  11.57               11.97             8.91
# 414                  10.74               10.28             8.28
# 413                  10.99               11.43             8.76
#
# Date_Name  2014-15 Winter_FPM  ...  2015 Summer_O3  2017 Summer_O3  \
# 503                      8.06  ...           34.09           28.81
# 502                      8.51  ...           32.47           28.74
# 501                      8.72  ...           30.39           27.50
# 414                      7.39  ...           37.54           35.30
# 413                      8.23  ...           32.64           31.85
#
# Date_Name  2009-2010 Average Summer 2-Year_O3  2005_TrafficDens_Vehicle  \
# 503                                     30.23                       6.3
# 502                                     30.45                      12.5
# 501                                     28.99                      12.8
# 414                                     30.55                       5.3
# 413                                     28.70                      30.4
#
# Date_Name  2016_TrafficDens_Vehicle  2016_TrafficDens_Car  \
# 503                             6.5                   6.3
# 502                            11.8                  11.1
# 501                            11.3                  10.7
# 414                             6.9                   6.8
# 413                            30.8                  30.1
#
# Date_Name  2005_TrafficDens_Car  2016_TrafficDens_Truck  \
# 503                         5.9                     0.2
# 502                        11.7                     0.6
# 501                        12.1                     0.5
# 414                         5.1                     0.2
# 413                        29.7                     0.6
#
# Date_Name  2005_TrafficDens_Truck                            CD_Name
# 503                           0.4  Tottenville and Great Kills (CD3)
# 502                           0.7  South Beach and Willowbrook (CD2)
# 501                           0.6     St. George and Stapleton (CD1)
# 414                           0.2  Rockaway and Broad Channel (CD14)
# 413                           0.6              Queens Village (CD13)
#
# [5 rows x 66 columns]

# %%
sorted(air_qual.columns)
# Out:
# ['2005_TrafficDens_Car',
#  '2005_TrafficDens_Truck',
#  '2005_TrafficDens_Vehicle',
#  '2008-09 Winter_FPM',
#  '2008-09 Winter_NO2',
#  '2008-09 Winter_SO2',
#  '2009 Summer_FPM',
#  '2009 Summer_NO2',
#  '2009 Summer_O3',
#  '2009-10 Winter_FPM',
#  '2009-10 Winter_NO2',
#  '2009-10 Winter_SO2',
#  '2009-2010 Average Summer 2-Year_O3',
#  '2010 Summer_FPM',
#  '2010 Summer_NO2',
#  '2010 Summer_O3',
#  '2010-11 Winter_FPM',
#  '2010-11 Winter_NO2',
#  '2010-11 Winter_SO2',
#  '2011 Summer_FPM',
#  '2011 Summer_NO2',
#  '2011 Summer_O3',
#  '2011-12 Winter_FPM',
#  '2011-12 Winter_NO2',
#  '2011-12 Winter_SO2',
#  '2012 Summer_FPM',
#  '2012 Summer_NO2',
#  '2012 Summer_O3',
#  '2012-13 Winter_FPM',
#  '2012-13 Winter_NO2',
#  '2012-13 Winter_SO2',
#  '2013 Summer_FPM',
#  '2013 Summer_NO2',
#  '2013 Summer_O3',
#  '2013-14 Winter_FPM',
#  '2013-14 Winter_NO2',
#  '2013-14 Winter_SO2',
#  '2014 Summer_FPM',
#  '2014 Summer_NO2',
#  '2014 Summer_O3',
#  '2014-15 Winter_FPM',
#  '2014-15 Winter_NO2',
#  '2014-15 Winter_SO2',
#  '2015 Summer_FPM',
#  '2015 Summer_NO2',
#  '2015 Summer_O3',
#  '2015-16 Winter_FPM',
#  '2015-16 Winter_NO2',
#  '2015-16 Winter_SO2',
#  '2016 Summer_FPM',
#  '2016 Summer_NO2',
#  '2016 Summer_O3',
#  '2016-17 Winter_FPM',
#  '2016-17 Winter_NO2',
#  '2016_TrafficDens_Car',
#  '2016_TrafficDens_Truck',
#  '2016_TrafficDens_Vehicle',
#  '2017 Summer_FPM',
#  '2017 Summer_NO2',
#  '2017 Summer_O3',
#  '2017-18 Winter_FPM',
#  '2017-18 Winter_NO2',
#  '2018 Summer_FPM',
#  '2018 Summer_NO2',
#  '2018 Summer_O3',
#  'CD_Name']

# %%
# Drop redundant column
air_qual.drop(columns='2009-2010 Average Summer 2-Year_O3', inplace=True)

# Drop measurements from after Summer 2017
air_qual.drop(columns=['2017-18 Winter_FPM',
 '2017-18 Winter_NO2',
 '2018 Summer_FPM',
 '2018 Summer_NO2',
 '2018 Summer_O3'], inplace=True)

# %%
# Create features indicating pct overall change
# Traffic Density
air_qual['TD_Car_05-16Chg'] = (air_qual['2016_TrafficDens_Car'] - air_qual['2005_TrafficDens_Car']) / air_qual['2005_TrafficDens_Car']
air_qual['TD_Truck_05-16Chg'] = (air_qual['2016_TrafficDens_Truck'] - air_qual['2005_TrafficDens_Truck']) / air_qual['2005_TrafficDens_Truck']
air_qual['TD_Vehicle_05-16Chg'] = (air_qual['2016_TrafficDens_Vehicle'] - air_qual['2005_TrafficDens_Vehicle']) / air_qual['2005_TrafficDens_Vehicle']
# FPM
air_qual['Summ_FPM_09-17Chg'] = (air_qual['2017 Summer_FPM'] - air_qual['2009 Summer_FPM']) / air_qual['2009 Summer_FPM']
air_qual['Wint_FPM_09-17Chg'] = (air_qual['2016-17 Winter_FPM'] - air_qual['2008-09 Winter_FPM']) / air_qual['2008-09 Winter_FPM']
# NO2
air_qual['Summ_NO2_09-17Chg'] = (air_qual['2017 Summer_NO2'] - air_qual['2009 Summer_NO2']) / air_qual['2009 Summer_NO2']
air_qual['Wint_NO2_09-17Chg'] = (air_qual['2016-17 Winter_NO2'] - air_qual['2008-09 Winter_NO2']) / air_qual['2008-09 Winter_NO2']
# SO2
air_qual['SO2_09-16Chg'] = (air_qual['2015-16 Winter_SO2'] - air_qual['2008-09 Winter_SO2']) / air_qual['2008-09 Winter_SO2']
# O3
air_qual['O3_09-17Chg'] = (air_qual['2017 Summer_O3'] - air_qual['2009 Summer_O3']) / air_qual['2009 Summer_O3']

# %%
air_qual.shape
# Out:
# (59, 69)

# %%
# Add geometry for Tableau

def rename_cols(col):
    return col.replace('Summer', 'S').replace('Winter', 'W').replace(' ', '').replace('20', '').replace('TrafficDens', 'TD')


airqual_geom = gpd.GeoDataFrame(air_qual).sort_index()
cd.set_index('BoroCD', inplace=True)
cd.sort_index(inplace=True)
airqual_geom['geometry'] = cd['geometry']
airqual_geom.rename(columns=rename_cols, inplace=True)
airqual_geom.to_file('../data/air_quality/air_qual_gdf.shp')
# Out:
# /var/folders/by/f27ws03s62v8tb7315j3kxm80000gn/T/ipykernel_40425/3845585784.py:12: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   airqual_geom.to_file('../data/air_quality/air_qual_gdf.shp')

# %%
airqual_geom.columns
# Out:
# Index(['13S_FPM', '16-17W_FPM', '09-10W_FPM', '12-13W_FPM', '09S_FPM',
#        '10S_FPM', '10-11W_FPM', '15S_FPM', '14-15W_FPM', '15-16W_FPM',
#        '11-12W_FPM', '12S_FPM', '16S_FPM', '17S_FPM', '08-09W_FPM', '11S_FPM',
#        '13-14W_FPM', '14S_FPM', '11S_NO2', '13-14W_NO2', '17S_NO2', '14S_NO2',
#        '16S_NO2', '08-09W_NO2', '12-13W_NO2', '09S_NO2', '11-12W_NO2',
#        '12S_NO2', '14-15W_NO2', '15-16W_NO2', '16-17W_NO2', '09-10W_NO2',
#        '10-11W_NO2', '10S_NO2', '13S_NO2', '15S_NO2', '10-11W_SO2',
#        '11-12W_SO2', '08-09W_SO2', '12-13W_SO2', '13-14W_SO2', '14-15W_SO2',
#        '15-16W_SO2', '09-10W_SO2', '09S_O3', '13S_O3', '11S_O3', '14S_O3',
#        '16S_O3', '10S_O3', '12S_O3', '15S_O3', '17S_O3', '05_TD_Vehicle',
#        '16_TD_Vehicle', '16_TD_Car', '05_TD_Car', '16_TD_Truck', '05_TD_Truck',
#        'CD_Name', 'TD_Car_05-16Chg', 'TD_Truck_05-16Chg',
#        'TD_Vehicle_05-16Chg', 'Summ_FPM_09-17Chg', 'Wint_FPM_09-17Chg',
#        'Summ_NO2_09-17Chg', 'Wint_NO2_09-17Chg', 'SO2_09-16Chg', 'O3_09-17Chg',
#        'geometry'],
#       dtype='object', name='Date_Name')
