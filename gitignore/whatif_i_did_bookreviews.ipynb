# %%
import pandas as pd
import requests
import time

# %%
api_key = 'I5rjA2VR3lcCtHcI1UqT0eLEaxrWKtRv'
furl = f"https://api.nytimes.com/svc/books/v3/lists/current/hardcover-fiction.json?api-key={api_key}"
nurl = f"https://api.nytimes.com/svc/books/v3/lists/current/hardcover-nonfiction.json?api-key={api_key}"

# %%
requestHeaders = {
    "Accept": "application/json"
  }

fres = requests.get(furl, headers=requestHeaders)
nres = requests.get(nurl, headers=requestHeaders)

# %%
res.status_code
# Out:
# 200

# %%
data = res.json()['results']
books = data['books']
prev_date = data['previous_published_date']

# %%
pd.DataFrame(books)
# Out:
#     rank  rank_last_week  weeks_on_list  asterisk  dagger primary_isbn10  \
# 0      1               0              1         0       0     075955434X
# 1      2               0              1         0       0     0593331265
# 2      3               1              3         0       0     0063003058
# 3      4               0              1         0       0     125027320X
# 4      5               0              1         0       0     1984821717
# 5      6               2              2         0       0     1982166797
# 6      7               0              1         0       0     0062892401
# 7      8               6             66         0       0     0525559477
# 8      9               4              4         0       0     1635574072
# 9     10               5              2         0       0     0062997424
# 10    11               8             23         0       0     0735222355
# 11    12               7             10         0       0     0593356152
# ...
